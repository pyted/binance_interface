# %% [markdown]
# ## 1. APP 币本位合约交易-限价单开仓函数总览

# %% [markdown]
# |方法|解释|
# |:---|:---|
# |open_limit|限价单开仓|

# %%
from binance_interface.app import BinanceCM
from pprint import pprint

# %% [markdown]
# ## 2. 模型实例化

# %%
# 转发：需搭建转发服务器，可参考：https://github.com/pyted/binance_resender
proxy_host = None
key = 'xxxx'
secret = 'xxxx'

binanceCM = BinanceCM(
    key=key, secret=secret,
    proxy_host=proxy_host
)
trade = binanceCM.trade

# %% [markdown]
# ## 3. 同步 非堵塞 限价开仓（购买）

# %%
open_limit3 = trade.open_limit(
    symbol='ETHUSD_PERP',  # 产品
    marginType='ISOLATED',  # 保证金模式 ISOLATED: 逐仓 CROSSED: 全仓
    positionSide='LONG',  # 持仓方向 LONG: 多单 SHORT: 空单
    leverage=1,  # 杠杆
    openPrice=2100,  # 开仓价格
    openMoney=0.01,  # 开仓金额 (货币数量) 开仓金额openMoney和开仓数量quantity必须输入其中一个 优先级：quantity > openMoney
    # quantity=2,  # 开仓数量（合约张数）
    block=False,  # 是否以堵塞的模式
    newClientOrderId='',  # 客户自定义订单ID
)
pprint(open_limit3)
# Out:
# {'cancel_result': None,
#  'error_result': None,
#  'func_param': {'block': False,
#                 'callback': None,
#                 'cancel': True,
#                 'delay': 0.2,
#                 'errorback': None,
#                 'leverage': 1,
#                 'marginType': 'ISOLATED',
#                 'meta': {},
#                 'newClientOrderId': '',
#                 'newThread': False,
#                 'openMoney': 0.01,
#                 'openPrice': 2100,
#                 'positionSide': 'LONG',
#                 'quantity': None,
#                 'symbol': 'ETHUSD_PERP',
#                 'timeout': 60},
#  'get_order_result': None,
#  'meta': {},
#  'request_param': {'newClientOrderId': '',
#                    'positionSide': 'LONG',
#                    'price': '2100.00',
#                    'quantity': '2',
#                    'side': 'BUY',
#                    'symbol': 'ETHUSD_PERP',
#                    'timeInForce': 'GTC',
#                    'type': 'LIMIT'},
#  'set_order_result': {'code': 200,
#                       'data': {'avgPrice': '0.00',
#                                'clientOrderId': '9q9vEr4FVI11JDCKYoTjd1',
#                                'closePosition': False,
#                                'cumBase': '0',
#                                'cumQty': '0',
#                                'executedQty': '0',
#                                'orderId': 70557524293,
#                                'origQty': '2',
#                                'origType': 'LIMIT',
#                                'pair': 'ETHUSD',
#                                'positionSide': 'LONG',
#                                'price': '2100',
#                                'priceProtect': False,
#                                'reduceOnly': False,
#                                'side': 'BUY',
#                                'status': 'NEW',
#                                'stopPrice': '0',
#                                'symbol': 'ETHUSD_PERP',
#                                'timeInForce': 'GTC',
#                                'type': 'LIMIT',
#                                'updateTime': 1706199116863,
#                                'workingType': 'CONTRACT_PRICE'},
#                       'msg': ''},
#  'status': None,
#  'symbol': 'ETHUSD_PERP'}

# %% [markdown]
# ## 4. 同步 堵塞 限价开仓

# %%
# 超时，可选择是否取消订单
# 设置block、timeout、delay与cancel
open_limit4 = trade.open_limit(
    symbol='ETHUSD_PERP',  # 产品
    marginType='ISOLATED',  # 保证金模式 ISOLATED: 逐仓 CROSSED: 全仓
    positionSide='LONG',  # 持仓方向 LONG: 多单 SHORT: 空单
    leverage=1,  # 杠杆
    openPrice=2100,  # 开仓价格
    # openMoney=0.01,  # 开仓金额(货币数量) 开仓金额openMoney和开仓数量quantity必须输入其中一个 优先级：quantity > openMoney
    quantity=1,  # 开仓数量（合约张数）

    block=True,  # 是否以堵塞的模式
    timeout=5,  # 等待订单成功的超时时间（秒）
    delay=0.2,  # 检测订单状态的间隔 (秒)
    cancel=True,  # 订单超时后是否取消
)

pprint(open_limit4)
# Out:
# {'cancel_result': {'code': 200,
#                    'data': {'avgPrice': '0.00',
#                             'clientOrderId': '8tMJzttDN3NU69rcDKEJq1',
#                             'closePosition': False,
#                             'cumBase': '0',
#                             'cumQty': '0',
#                             'executedQty': '0',
#                             'orderId': 70557591316,
#                             'origQty': '1',
#                             'origType': 'LIMIT',
#                             'pair': 'ETHUSD',
#                             'positionSide': 'LONG',
#                             'price': '2100',
#                             'priceProtect': False,
#                             'reduceOnly': False,
#                             'side': 'BUY',
#                             'status': 'CANCELED',
#                             'stopPrice': '0',
#                             'symbol': 'ETHUSD_PERP',
#                             'timeInForce': 'GTC',
#                             'type': 'LIMIT',
#                             'updateTime': 1706199173979,
#                             'workingType': 'CONTRACT_PRICE'},
#                    'msg': ''},
#  'error_result': None,
#  'func_param': {'block': True,
#                 'callback': None,
#                 'cancel': True,
#                 'delay': 0.2,
#                 'errorback': None,
#                 'leverage': 1,
#                 'marginType': 'ISOLATED',
#                 'meta': {},
#                 'newClientOrderId': '',
#                 'newThread': False,
#                 'openMoney': None,
#                 'openPrice': 2100,
#                 'positionSide': 'LONG',
#                 'quantity': 1,
#                 'symbol': 'ETHUSD_PERP',
#                 'timeout': 5},
#  'get_order_result': {'code': 200,
#                       'data': {'avgPrice': '0.00',
#                                'clientOrderId': '8tMJzttDN3NU69rcDKEJq1',
#                                'closePosition': False,
#                                'cumBase': '0',
#                                'executedQty': '0',
#                                'orderId': 70557591316,
#                                'origQty': '1',
#                                'origType': 'LIMIT',
#                                'pair': 'ETHUSD',
#                                'positionSide': 'LONG',
#                                'price': '2100',
#                                'priceProtect': False,
#                                'reduceOnly': False,
#                                'side': 'BUY',
#                                'status': 'CANCELED',
#                                'stopPrice': '0',
#                                'symbol': 'ETHUSD_PERP',
#                                'time': 1706199167701,
#                                'timeInForce': 'GTC',
#                                'type': 'LIMIT',
#                                'updateTime': 1706199173979,
#                                'workingType': 'CONTRACT_PRICE'},
#                       'msg': ''},
#  'meta': {},
#  'request_param': {'newClientOrderId': '',
#                    'positionSide': 'LONG',
#                    'price': '2100.00',
#                    'quantity': '1',
#                    'side': 'BUY',
#                    'symbol': 'ETHUSD_PERP',
#                    'timeInForce': 'GTC',
#                    'type': 'LIMIT'},
#  'set_order_result': {'code': 200,
#                       'data': {'avgPrice': '0.00',
#                                'clientOrderId': '8tMJzttDN3NU69rcDKEJq1',
#                                'closePosition': False,
#                                'cumBase': '0',
#                                'cumQty': '0',
#                                'executedQty': '0',
#                                'orderId': 70557591316,
#                                'origQty': '1',
#                                'origType': 'LIMIT',
#                                'pair': 'ETHUSD',
#                                'positionSide': 'LONG',
#                                'price': '2100',
#                                'priceProtect': False,
#                                'reduceOnly': False,
#                                'side': 'BUY',
#                                'status': 'NEW',
#                                'stopPrice': '0',
#                                'symbol': 'ETHUSD_PERP',
#                                'timeInForce': 'GTC',
#                                'type': 'LIMIT',
#                                'updateTime': 1706199167701,
#                                'workingType': 'CONTRACT_PRICE'},
#                       'msg': ''},
#  'status': 'CANCELED',
#  'symbol': 'ETHUSD_PERP'}

# %% [markdown]
# ## 5. 同步 堵塞 限价开仓 回调函数

# %%
# 执行成功回调
def callback5(information):
    print('callback')
    pprint(information)


# 执行错误回调
def errorback5(information):
    print('errorback')
    pprint(information)

# %%
# 设置callback与errorback
open_limit5 = trade.open_limit(
    symbol='ETHUSD_PERP',  # 产品
    marginType='ISOLATED',  # 保证金模式 ISOLATED: 逐仓 CROSSED: 全仓
    positionSide='LONG',  # 持仓方向 LONG: 多单 SHORT: 空单
    leverage=1,  # 杠杆
    openPrice=2100,  # 开仓价格
    openMoney=0.01,  # 开仓金额(货币数量) 开仓金额openMoney和开仓数量quantity必须输入其中一个 优先级：quantity > openMoney
    # quantity=2,  # 开仓数量（合约张数）
    block=True,  # 是否以堵塞的模式
    timeout=5,  # 等待订单成功的超时时间（秒）
    delay=0.2,  # 检测订单状态的间隔 (秒)
    cancel=True,  # 订单超时后是否取消

    callback=callback5,  # 开仓成功触发的回调函数
    errorback=errorback5,  # 开仓失败触发的回调函数
)
# Out:
# callback
# {'cancel_result': {'code': 200,
#                    'data': {'avgPrice': '0.00',
#                             'clientOrderId': 'NGLg85FosPZy60hUwujq8i',
#                             'closePosition': False,
#                             'cumBase': '0',
#                             'cumQty': '0',
#                             'executedQty': '0',
#                             'orderId': 70557671336,
#                             'origQty': '2',
#                             'origType': 'LIMIT',
#                             'pair': 'ETHUSD',
#                             'positionSide': 'LONG',
#                             'price': '2100',
#                             'priceProtect': False,
#                             'reduceOnly': False,
#                             'side': 'BUY',
#                             'status': 'CANCELED',
#                             'stopPrice': '0',
#                             'symbol': 'ETHUSD_PERP',
#                             'timeInForce': 'GTC',
#                             'type': 'LIMIT',
#                             'updateTime': 1706199225621,
#                             'workingType': 'CONTRACT_PRICE'},
#                    'msg': ''},
#  'error_result': None,
#  'func_param': {'block': True,
#                 'callback': <function callback5 at 0x7fddf12fadc0>,
#                 'cancel': True,
#                 'delay': 0.2,
#                 'errorback': <function errorback5 at 0x7fddf12fa5e0>,
#                 'leverage': 1,
#                 'marginType': 'ISOLATED',
#                 'meta': {},
#                 'newClientOrderId': '',
#                 'newThread': False,
#                 'openMoney': 0.01,
#                 'openPrice': 2100,
#                 'positionSide': 'LONG',
#                 'quantity': None,
#                 'symbol': 'ETHUSD_PERP',
#                 'timeout': 5},
#  'get_order_result': {'code': 200,
#                       'data': {'avgPrice': '0.00',
#                                'clientOrderId': 'NGLg85FosPZy60hUwujq8i',
#                                'closePosition': False,
#                                'cumBase': '0',
#                                'executedQty': '0',
#                                'orderId': 70557671336,
#                                'origQty': '2',
#                                'origType': 'LIMIT',
#                                'pair': 'ETHUSD',
#                                'positionSide': 'LONG',
#                                'price': '2100',
#                                'priceProtect': False,
#                                'reduceOnly': False,
#                                'side': 'BUY',
#                                'status': 'CANCELED',
#                                'stopPrice': '0',
#                                'symbol': 'ETHUSD_PERP',
#                                'time': 1706199219943,
#                                'timeInForce': 'GTC',
#                                'type': 'LIMIT',
#                                'updateTime': 1706199225621,
#                                'workingType': 'CONTRACT_PRICE'},
#                       'msg': ''},
#  'meta': {},
#  'request_param': {'newClientOrderId': '',
#                    'positionSide': 'LONG',
#                    'price': '2100.00',
#                    'quantity': '2',
#                    'side': 'BUY',
#                    'symbol': 'ETHUSD_PERP',
#                    'timeInForce': 'GTC',
#                    'type': 'LIMIT'},
#  'set_order_result': {'code': 200,
#                       'data': {'avgPrice': '0.00',
#                                'clientOrderId': 'NGLg85FosPZy60hUwujq8i',
#                                'closePosition': False,
#                                'cumBase': '0',
#                                'cumQty': '0',
#                                'executedQty': '0',
#                                'orderId': 70557671336,
#                                'origQty': '2',
#                                'origType': 'LIMIT',
#                                'pair': 'ETHUSD',
#                                'positionSide': 'LONG',
#                                'price': '2100',
#                                'priceProtect': False,
#                                'reduceOnly': False,
#                                'side': 'BUY',
#                                'status': 'NEW',
#                                'stopPrice': '0',
#                                'symbol': 'ETHUSD_PERP',
#                                'timeInForce': 'GTC',
#                                'type': 'LIMIT',
#                                'updateTime': 1706199219943,
#                                'workingType': 'CONTRACT_PRICE'},
#                       'msg': ''},
#  'status': 'CANCELED',
#  'symbol': 'ETHUSD_PERP'}

# %% [markdown]
# ## 6. 异步 堵塞 限价开仓（购买）回调函数

# %%
# 执行成功回调
def callback6(information):
    print('thread callback')
    pprint(information)


# 执行错误回调
def errorback6(information):
    print('thread errorback')
    pprint(information)

# %%
# 设置newThread=True
open_limit6 = trade.open_limit(
    symbol='ETHUSD_PERP',  # 产品
    marginType='ISOLATED',  # 保证金模式 ISOLATED: 逐仓 CROSSED: 全仓
    positionSide='LONG',  # 持仓方向 LONG: 多单 SHORT: 空单
    leverage=1,  # 杠杆
    openPrice=2100,  # 开仓价格
    openMoney=0.01,  # 开仓金额(货币数量) 开仓金额openMoney和开仓数量quantity必须输入其中一个 优先级：quantity > openMoney
    # quantity=2,  # 开仓数量（合约张数）
    block=True,  # 是否以堵塞的模式
    timeout=5,  # 等待订单成功的超时时间（秒）
    delay=0.2,  # 检测订单状态的间隔 (秒)
    cancel=True,  # 订单超时后是否取消
    callback=callback6,  # 开仓成功触发的回调函数
    errorback=errorback6,  # 开仓失败触发的回调函数

    newThread=True,
)
pprint(open_limit6)
print('-' * 30)
# Out:
# <Thread(Thread-5, started 123145674633216)>
# ------------------------------
# thread callback
# {'cancel_result': {'code': 200,
#                    'data': {'avgPrice': '0.00',
#                             'clientOrderId': 'J46hVbUeETJi2ROP5hlvUd',
#                             'closePosition': False,
#                             'cumBase': '0',
#                             'cumQty': '0',
#                             'executedQty': '0',
#                             'orderId': 70557736968,
#                             'origQty': '2',
#                             'origType': 'LIMIT',
#                             'pair': 'ETHUSD',
#                             'positionSide': 'LONG',
#                             'price': '2100',
#                             'priceProtect': False,
#                             'reduceOnly': False,
#                             'side': 'BUY',
#                             'status': 'CANCELED',
#                             'stopPrice': '0',
#                             'symbol': 'ETHUSD_PERP',
#                             'timeInForce': 'GTC',
#                             'type': 'LIMIT',
#                             'updateTime': 1706199271276,
#                             'workingType': 'CONTRACT_PRICE'},
#                    'msg': ''},
#  'error_result': None,
#  'func_param': {'block': True,
#                 'callback': <function callback6 at 0x7fddf12fa790>,
#                 'cancel': True,
#                 'delay': 0.2,
#                 'errorback': <function errorback6 at 0x7fddf12faf70>,
#                 'leverage': 1,
#                 'marginType': 'ISOLATED',
#                 'meta': {},
#                 'newClientOrderId': '',
#                 'newThread': True,
#                 'openMoney': 0.01,
#                 'openPrice': 2100,
#                 'positionSide': 'LONG',
#                 'quantity': None,
#                 'symbol': 'ETHUSD_PERP',
#                 'timeout': 5},
#  'get_order_result': {'code': 200,
#                       'data': {'avgPrice': '0.00',
#                                'clientOrderId': 'J46hVbUeETJi2ROP5hlvUd',
#                                'closePosition': False,
#                                'cumBase': '0',
#                                'executedQty': '0',
#                                'orderId': 70557736968,
#                                'origQty': '2',
#                                'origType': 'LIMIT',
#                                'pair': 'ETHUSD',
#                                'positionSide': 'LONG',
#                                'price': '2100',
#                                'priceProtect': False,
#                                'reduceOnly': False,
#                                'side': 'BUY',
#                                'status': 'CANCELED',
#                                'stopPrice': '0',
#                                'symbol': 'ETHUSD_PERP',
#                                'time': 1706199265244,
#                                'timeInForce': 'GTC',
#                                'type': 'LIMIT',
#                                'updateTime': 1706199271276,
#                                'workingType': 'CONTRACT_PRICE'},
#                       'msg': ''},
#  'meta': {},
#  'request_param': {'newClientOrderId': '',
#                    'positionSide': 'LONG',
#                    'price': '2100.00',
#                    'quantity': '2',
#                    'side': 'BUY',
#                    'symbol': 'ETHUSD_PERP',
#                    'timeInForce': 'GTC',
#                    'type': 'LIMIT'},
#  'set_order_result': {'code': 200,
#                       'data': {'avgPrice': '0.00',
#                                'clientOrderId': 'J46hVbUeETJi2ROP5hlvUd',
#                                'closePosition': False,
#                                'cumBase': '0',
#                                'cumQty': '0',
#                                'executedQty': '0',
#                                'orderId': 70557736968,
#                                'origQty': '2',
#                                'origType': 'LIMIT',
#                                'pair': 'ETHUSD',
#                                'positionSide': 'LONG',
#                                'price': '2100',
#                                'priceProtect': False,
#                                'reduceOnly': False,
#                                'side': 'BUY',
#                                'status': 'NEW',
#                                'stopPrice': '0',
#                                'symbol': 'ETHUSD_PERP',
#                                'timeInForce': 'GTC',
#                                'type': 'LIMIT',
#                                'updateTime': 1706199265244,
#                                'workingType': 'CONTRACT_PRICE'},
#                       'msg': ''},
#  'status': 'CANCELED',
#  'symbol': 'ETHUSD_PERP'}
