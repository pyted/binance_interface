# %% [markdown]
# ## 1. APP 币本位合约交易账户函数总览

# %% [markdown]
# |方法|解释|
# |:---|:---|
# |get_account|获取账户信息|
# |get_balance|获取单个产品余额|
# |get_balances|获取全部产品余额（列表格式）|
# |get_balancesMap|获取全部产品余额（字典格式）|
# |set_leverage|调整开仓杠杆|
# |set_marginType|更改持仓模式|
# |get_position|获取单个产品的持仓信息|
# |get_positions|获取全部产品的持仓信息（列表格式）|
# |get_positionsMap|获取全部产品的持仓信息字典（字典格式）|

# %% [markdown]
# ## 2. 模型实例化

# %%
from binance_interface.app import BinanceCM
from binance_interface.app.utils import eprint

# %%
# 转发：需搭建转发服务器，可参考：https://github.com/pyted/binance_resender
proxy_host = None
key = 'xxxx'
secret = 'xxxx'

binanceCM = BinanceCM(
    key=key, secret=secret,
    proxy_host=proxy_host
)
account = binanceCM.account

# %% [markdown]
# ## 3. 获取账户信息 get_account

# %%
account_result = account.get_account()
eprint(account_result)
# Out:
# {'code': 200,
#  'data': {'feeTier': 0,
#           'canTrade': True,
#           'canDeposit': True,
#           'canWithdraw': True,
#           'updateTime': 0,
#           'assets': [{'asset': 'ADA',
#                       'walletBalance': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'marginBalance': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       '...': '......'},
#                      {'asset': 'ALGO',
#                       'walletBalance': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'marginBalance': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       '...': '......'},
#                      {'asset': 'KNC',
#                       'walletBalance': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'marginBalance': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       '...': '......'},
#                      {'asset': 'CHZ',
#                       'walletBalance': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'marginBalance': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       '...': '......'},
#                      {'asset': 'NEAR',
#                       'walletBalance': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'marginBalance': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       '...': '......'},
#                      '......'],
#           'positions': [{'symbol': 'BCHUSD_240628',
#                          'initialMargin': '0',
#                          'maintMargin': '0',
#                          'unrealizedProfit': '0.00000000',
#                          'positionInitialMargin': '0',
#                          '...': '......'},
#                         {'symbol': 'BCHUSD_240628',
#                          'initialMargin': '0',
#                          'maintMargin': '0',
#                          'unrealizedProfit': '0.00000000',
#                          'positionInitialMargin': '0',
#                          '...': '......'},
#                         {'symbol': 'BCHUSD_240628',
#                          'initialMargin': '0',
#                          'maintMargin': '0',
#                          'unrealizedProfit': '0.00000000',
#                          'positionInitialMargin': '0',
#                          '...': '......'},
#                         {'symbol': 'NEARUSD_PERP',
#                          'initialMargin': '0',
#                          'maintMargin': '0',
#                          'unrealizedProfit': '0.00000000',
#                          'positionInitialMargin': '0',
#                          '...': '......'},
#                         {'symbol': 'NEARUSD_PERP',
#                          'initialMargin': '0',
#                          'maintMargin': '0',
#                          'unrealizedProfit': '0.00000000',
#                          'positionInitialMargin': '0',
#                          '...': '......'},
#                         '......']},
#  'msg': ''}

# %% [markdown]
# ## 4. 获取单个产品余额 get_balance

# %%
# 等价于下面代码：account.get_balance(symbol='BTCUSDT',base_asset='USDT')
balance_result = account.get_balance(asset='BTC')
eprint(balance_result)
# Out:
# {'code': 200,
#  'data': {'accountAlias': 'FzTiAusRuXmYTisR',
#           'asset': 'BTC',
#           'balance': '0.00148851',
#           'withdrawAvailable': '0.00148851',
#           'updateTime': 1706192301743,
#           'crossWalletBalance': '0.00148851',
#           'crossUnPnl': '0.00000000',
#           'availableBalance': '0.00148851'},
#  'msg': ''}

# %% [markdown]
# ## 5. 获取全部产品余额（列表格式） get_balances

# %%
# 参数assets默认为[]，表示全部货币
balances_result = account.get_balances()
eprint(balances_result)
# Out:
# {'code': 200,
#  'data': [{'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'APE',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'FTM',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'TRX',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'NEAR',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'LUNA',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'XRP',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'ROSE',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'LTC',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'ALGO',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'UNI',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'AVAX',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'ETH',
#            'balance': '0.03425805',
#            'withdrawAvailable': '0.02520429',
#            'updateTime': 1706192196816,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'DOT',
#            'balance': '7.74147373',
#            'withdrawAvailable': '7.66410913',
#            'updateTime': 1706192466123,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'EOS',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'CHZ',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'MATIC',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'AAVE',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'ICX',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'RUNE',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'CRV',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'OP',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'ENS',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'AXS',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'APT',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'ZIL',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'XLM',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'BTC',
#            'balance': '0.00148851',
#            'withdrawAvailable': '0.00148851',
#            'updateTime': 1706192301743,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'BCH',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'THETA',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'GALA',
#            'balance': '0.00000000',
#            'withdrawAvailable': '0.00000000',
#            'updateTime': 0,
#            '...': '......'},
#           '......'],
#  'msg': ''}

# %%
# 指定多个货币
balances_result = account.get_balances(assets=['BTC', 'ETH'])
eprint(balances_result)
# Out:
# {'code': 200,
#  'data': [{'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'BTC',
#            'balance': '0.00148851',
#            'withdrawAvailable': '0.00148851',
#            'updateTime': 1706192301743,
#            '...': '......'},
#           {'accountAlias': 'FzTiAusRuXmYTisR',
#            'asset': 'ETH',
#            'balance': '0.03425805',
#            'withdrawAvailable': '0.02520429',
#            'updateTime': 1706192196816,
#            '...': '......'}],
#  'msg': ''}

# %% [markdown]
# ## 6. 获取全部产品余额（字典格式）

# %%
# 参数assets默认为[]，表示全部货币
balancesMap_result = account.get_balancesMap()
eprint(balancesMap_result)
# Out:
# {'code': 200,
#  'data': {'ATOM': {'accountAlias': 'FzTiAusRuXmYTisR',
#                    'asset': 'ATOM',
#                    'balance': '0.00000000',
#                    'withdrawAvailable': '0.00000000',
#                    'updateTime': 0,
#                    '...': '......'},
#           'LINK': {'accountAlias': 'FzTiAusRuXmYTisR',
#                    'asset': 'LINK',
#                    'balance': '0.00000000',
#                    'withdrawAvailable': '0.00000000',
#                    'updateTime': 0,
#                    '...': '......'},
#           'XRP': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'XRP',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'LTC': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'LTC',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'ROSE': {'accountAlias': 'FzTiAusRuXmYTisR',
#                    'asset': 'ROSE',
#                    'balance': '0.00000000',
#                    'withdrawAvailable': '0.00000000',
#                    'updateTime': 0,
#                    '...': '......'},
#           'XTZ': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'XTZ',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'ADA': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'ADA',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'APT': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'APT',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'BCH': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'BCH',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'ALGO': {'accountAlias': 'FzTiAusRuXmYTisR',
#                    'asset': 'ALGO',
#                    'balance': '0.00000000',
#                    'withdrawAvailable': '0.00000000',
#                    'updateTime': 0,
#                    '...': '......'},
#           'BTC': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'BTC',
#                   'balance': '0.00148851',
#                   'withdrawAvailable': '0.00148851',
#                   'updateTime': 1706192301743,
#                   '...': '......'},
#           'DOGE': {'accountAlias': 'FzTiAusRuXmYTisR',
#                    'asset': 'DOGE',
#                    'balance': '0.00000000',
#                    'withdrawAvailable': '0.00000000',
#                    'updateTime': 0,
#                    '...': '......'},
#           'UNI': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'UNI',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'XLM': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'XLM',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'SOL': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'SOL',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'MANA': {'accountAlias': 'FzTiAusRuXmYTisR',
#                    'asset': 'MANA',
#                    'balance': '0.00000000',
#                    'withdrawAvailable': '0.00000000',
#                    'updateTime': 0,
#                    '...': '......'},
#           'SAND': {'accountAlias': 'FzTiAusRuXmYTisR',
#                    'asset': 'SAND',
#                    'balance': '0.00000000',
#                    'withdrawAvailable': '0.00000000',
#                    'updateTime': 0,
#                    '...': '......'},
#           'VET': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'VET',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'GALA': {'accountAlias': 'FzTiAusRuXmYTisR',
#                    'asset': 'GALA',
#                    'balance': '0.00000000',
#                    'withdrawAvailable': '0.00000000',
#                    'updateTime': 0,
#                    '...': '......'},
#           'ETC': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'ETC',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'APE': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'APE',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'MATIC': {'accountAlias': 'FzTiAusRuXmYTisR',
#                     'asset': 'MATIC',
#                     'balance': '0.00000000',
#                     'withdrawAvailable': '0.00000000',
#                     'updateTime': 0,
#                     '...': '......'},
#           'AAVE': {'accountAlias': 'FzTiAusRuXmYTisR',
#                    'asset': 'AAVE',
#                    'balance': '0.00000000',
#                    'withdrawAvailable': '0.00000000',
#                    'updateTime': 0,
#                    '...': '......'},
#           'XMR': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'XMR',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'DOT': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'DOT',
#                   'balance': '7.74147373',
#                   'withdrawAvailable': '7.66361129',
#                   'updateTime': 1706192466123,
#                   '...': '......'},
#           'GMT': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'GMT',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'OP': {'accountAlias': 'FzTiAusRuXmYTisR',
#                  'asset': 'OP',
#                  'balance': '0.00000000',
#                  'withdrawAvailable': '0.00000000',
#                  'updateTime': 0,
#                  '...': '......'},
#           'ETH': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'ETH',
#                   'balance': '0.03425805',
#                   'withdrawAvailable': '0.02520429',
#                   'updateTime': 1706192196816,
#                   '...': '......'},
#           'TRX': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'TRX',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'FIL': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'FIL',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           'CRV': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'CRV',
#                   'balance': '0.00000000',
#                   'withdrawAvailable': '0.00000000',
#                   'updateTime': 0,
#                   '...': '......'},
#           '...': '......'},
#  'msg': ''}

# %%
# 指定多个货币
balancesMap_result = account.get_balancesMap(assets=['BTC', 'ETH'])
eprint(balancesMap_result)
# Out:
# {'code': 200,
#  'data': {'ETH': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'ETH',
#                   'balance': '0.03425805',
#                   'withdrawAvailable': '0.02520429',
#                   'updateTime': 1706192196816,
#                   '...': '......'},
#           'BTC': {'accountAlias': 'FzTiAusRuXmYTisR',
#                   'asset': 'BTC',
#                   'balance': '0.00148851',
#                   'withdrawAvailable': '0.00148851',
#                   'updateTime': 1706192301743,
#                   '...': '......'}},
#  'msg': ''}

# %% [markdown]
# ## 7. 调整开仓杠杆 set_leverage

# %%
leverage_result = account.set_leverage(symbol='BTCUSD_PERP', leverage=2)
eprint(leverage_result)
# Out:
# {'code': 200, 'data': {'symbol': 'BTCUSD_PERP', 'leverage': 2, 'maxQty': '1500'}, 'msg': ''}

# %% [markdown]
# ## 8. 更改持仓模式 set_marginType

# %%
marginType_result = account.set_marginType(symbol='BTCUSD_PERP', marginType='CROSSED')
eprint(marginType_result)
# Out:
# {'code': 200, 'msg': 'success'}

# %%
marginType_result = account.set_marginType(symbol='BTCUSD_PERP', marginType='ISOLATED')
eprint(marginType_result)
# Out:
# {'code': 200, 'msg': 'success'}

# %% [markdown]
# ## 9. 获取单个产品的持仓信息 get_position

# %%
position_result = account.get_position(symbol='ETHUSD_PERP')
eprint(position_result)
# Out:
# {'code': 200,
#  'data': {'CROSSED': {'LONG': {}, 'SHORT': {}},
#           'ISOLATED': {'LONG': {'symbol': 'ETHUSD_PERP',
#                                 'initialMargin': '0.00452979',
#                                 'maintMargin': '0.00002264',
#                                 'unrealizedProfit': '0.00000075',
#                                 'positionInitialMargin': '0.00452979',
#                                 'openOrderInitialMargin': '0',
#                                 'leverage': '1',
#                                 'isolated': True,
#                                 'positionSide': 'LONG',
#                                 'entryPrice': '2207.22999998',
#                                 'maxQty': '50000',
#                                 'notionalValue': '0.00452980',
#                                 'isolatedWallet': '0.00452950',
#                                 'updateTime': 1706192161738,
#                                 'positionAmt': '1',
#                                 'breakEvenPrice': '2208.33361497'},
#                        'SHORT': {}}},
#  'msg': ''}

# %% [markdown]
# ## 10. 获取全部产品的持仓信息（列表格式） get_positions

# %%
# 参数symbols默认为[]，表示全部产品
positions_result = account.get_positions()
eprint(positions_result)
# Out:
# {'code': 200,
#  'data': {'CROSSED': {'LONG': [{'symbol': 'DOTUSD_PERP',
#                                 'initialMargin': '0.07763684',
#                                 'maintMargin': '0.03881842',
#                                 'unrealizedProfit': '-0.00018287',
#                                 'positionInitialMargin': '0.07763684',
#                                 'openOrderInitialMargin': '0',
#                                 'leverage': '20',
#                                 'isolated': False,
#                                 'positionSide': 'LONG',
#                                 'entryPrice': '6.44099999',
#                                 'maxQty': '25000',
#                                 'notionalValue': '1.55273682',
#                                 'isolatedWallet': '0',
#                                 'updateTime': 1706192466123,
#                                 'positionAmt': '1',
#                                 'breakEvenPrice': '6.44422049'},
#                                {'symbol': 'BNBUSD_PERP',
#                                 'initialMargin': '0.00170525',
#                                 'maintMargin': '0.00085262',
#                                 'unrealizedProfit': '-0.00004176',
#                                 'positionInitialMargin': '0.00170525',
#                                 'openOrderInitialMargin': '0',
#                                 'leverage': '20',
#                                 'isolated': False,
#                                 'positionSide': 'LONG',
#                                 'entryPrice': '293.57000000',
#                                 'maxQty': '2000',
#                                 'notionalValue': '0.03410518',
#                                 'isolatedWallet': '0',
#                                 'updateTime': 1706192408299,
#                                 'positionAmt': '1',
#                                 'breakEvenPrice': '293.71678499'}],
#                       'SHORT': []},
#           'ISOLATED': {'LONG': [{'symbol': 'ETHUSD_PERP',
#                                  'initialMargin': '0.00452961',
#                                  'maintMargin': '0.00002264',
#                                  'unrealizedProfit': '0.00000094',
#                                  'positionInitialMargin': '0.00452961',
#                                  'openOrderInitialMargin': '0',
#                                  'leverage': '1',
#                                  'isolated': True,
#                                  'positionSide': 'LONG',
#                                  'entryPrice': '2207.22999998',
#                                  'maxQty': '50000',
#                                  'notionalValue': '0.00452961',
#                                  'isolatedWallet': '0.00452950',
#                                  'updateTime': 1706192161738,
#                                  'positionAmt': '1',
#                                  'breakEvenPrice': '2208.33361497'}],
#                        'SHORT': []}},
#  'msg': ''}

# %%
# 指定多个产品
positions_result = account.get_positions(symbols=['ETHUSD_PERP', 'BNBUSD_PERP'])
eprint(positions_result)
# Out:
# {'code': 200,
#  'data': {'CROSSED': {'LONG': [{'symbol': 'BNBUSD_PERP',
#                                 'initialMargin': '0.00170528',
#                                 'maintMargin': '0.00085264',
#                                 'unrealizedProfit': '-0.00004235',
#                                 'positionInitialMargin': '0.00170528',
#                                 'openOrderInitialMargin': '0',
#                                 'leverage': '20',
#                                 'isolated': False,
#                                 'positionSide': 'LONG',
#                                 'entryPrice': '293.57000000',
#                                 'maxQty': '2000',
#                                 'notionalValue': '0.03410577',
#                                 'isolatedWallet': '0',
#                                 'updateTime': 1706192408299,
#                                 'positionAmt': '1',
#                                 'breakEvenPrice': '293.71678499'}],
#                       'SHORT': []},
#           'ISOLATED': {'LONG': [{'symbol': 'ETHUSD_PERP',
#                                  'initialMargin': '0.00452996',
#                                  'maintMargin': '0.00002264',
#                                  'unrealizedProfit': '0.00000060',
#                                  'positionInitialMargin': '0.00452996',
#                                  'openOrderInitialMargin': '0',
#                                  'leverage': '1',
#                                  'isolated': True,
#                                  'positionSide': 'LONG',
#                                  'entryPrice': '2207.22999998',
#                                  'maxQty': '50000',
#                                  'notionalValue': '0.00452996',
#                                  'isolatedWallet': '0.00452950',
#                                  'updateTime': 1706192161738,
#                                  'positionAmt': '1',
#                                  'breakEvenPrice': '2208.33361497'}],
#                        'SHORT': []}},
#  'msg': ''}

# %% [markdown]
# ## 11. 获取全部产品的持仓信息（字典格式） get_positionsMap

# %%
# 参数symbols默认为[]，表示全部产品
positionsMap_result = account.get_positionsMap()
eprint(positionsMap_result)
# Out:
# {'code': 200,
#  'data': {'CROSSED': {'LONG': {'BNBUSD_PERP': {'symbol': 'BNBUSD_PERP',
#                                                'initialMargin': '0.00170497',
#                                                'maintMargin': '0.00085248',
#                                                'unrealizedProfit': '-0.00003600',
#                                                'positionInitialMargin': '0.00170497',
#                                                'openOrderInitialMargin': '0',
#                                                'leverage': '20',
#                                                'isolated': False,
#                                                'positionSide': 'LONG',
#                                                'entryPrice': '293.57000000',
#                                                'maxQty': '2000',
#                                                'notionalValue': '0.03409943',
#                                                'isolatedWallet': '0',
#                                                'updateTime': 1706192408299,
#                                                'positionAmt': '1',
#                                                'breakEvenPrice': '293.71678499'},
#                                'DOTUSD_PERP': {'symbol': 'DOTUSD_PERP',
#                                                'initialMargin': '0.07766104',
#                                                'maintMargin': '0.03883052',
#                                                'unrealizedProfit': '-0.00066692',
#                                                'positionInitialMargin': '0.07766104',
#                                                'openOrderInitialMargin': '0',
#                                                'leverage': '20',
#                                                'isolated': False,
#                                                'positionSide': 'LONG',
#                                                'entryPrice': '6.44099999',
#                                                'maxQty': '25000',
#                                                'notionalValue': '1.55322087',
#                                                'isolatedWallet': '0',
#                                                'updateTime': 1706192466123,
#                                                'positionAmt': '1',
#                                                'breakEvenPrice': '6.44422049'}},
#                       'SHORT': {}},
#           'ISOLATED': {'LONG': {'ETHUSD_PERP': {'symbol': 'ETHUSD_PERP',
#                                                 'initialMargin': '0.00452974',
#                                                 'maintMargin': '0.00002264',
#                                                 'unrealizedProfit': '0.00000081',
#                                                 'positionInitialMargin': '0.00452974',
#                                                 'openOrderInitialMargin': '0',
#                                                 'leverage': '1',
#                                                 'isolated': True,
#                                                 'positionSide': 'LONG',
#                                                 'entryPrice': '2207.22999998',
#                                                 'maxQty': '50000',
#                                                 'notionalValue': '0.00452974',
#                                                 'isolatedWallet': '0.00452950',
#                                                 'updateTime': 1706192161738,
#                                                 'positionAmt': '1',
#                                                 'breakEvenPrice': '2208.33361497'}},
#                        'SHORT': {}}},
#  'msg': ''}

# %%
# 指定多个产品
positionsMap_result = account.get_positionsMap(symbols=['ETHUSD_PERP', 'BNBUSD_PERP'])
eprint(positionsMap_result)
# Out:
# {'code': 200,
#  'data': {'CROSSED': {'LONG': {'BNBUSD_PERP': {'symbol': 'BNBUSD_PERP',
#                                                'initialMargin': '0.00170483',
#                                                'maintMargin': '0.00085241',
#                                                'unrealizedProfit': '-0.00003326',
#                                                'positionInitialMargin': '0.00170483',
#                                                'openOrderInitialMargin': '0',
#                                                'leverage': '20',
#                                                'isolated': False,
#                                                'positionSide': 'LONG',
#                                                'entryPrice': '293.57000000',
#                                                'maxQty': '2000',
#                                                'notionalValue': '0.03409668',
#                                                'isolatedWallet': '0',
#                                                'updateTime': 1706192408299,
#                                                'positionAmt': '1',
#                                                'breakEvenPrice': '293.71678499'}},
#                       'SHORT': {}},
#           'ISOLATED': {'LONG': {'ETHUSD_PERP': {'symbol': 'ETHUSD_PERP',
#                                                 'initialMargin': '0.00452934',
#                                                 'maintMargin': '0.00002264',
#                                                 'unrealizedProfit': '0.00000122',
#                                                 'positionInitialMargin': '0.00452934',
#                                                 'openOrderInitialMargin': '0',
#                                                 'leverage': '1',
#                                                 'isolated': True,
#                                                 'positionSide': 'LONG',
#                                                 'entryPrice': '2207.22999998',
#                                                 'maxQty': '50000',
#                                                 'notionalValue': '0.00452934',
#                                                 'isolatedWallet': '0.00452950',
#                                                 'updateTime': 1706192161738,
#                                                 'positionAmt': '1',
#                                                 'breakEvenPrice': '2208.33361497'}},
#                        'SHORT': {}}},
#  'msg': ''}
